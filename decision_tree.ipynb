# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import tree

# %%
dataset = pd.read_csv("./Datasets/Social_Network_Ads.csv")

X = dataset.iloc[:,[1,2,3]].values
y = dataset.iloc[:, -1].values

# %%
encoder = LabelEncoder()
X[:, 0] = encoder.fit_transform(X[:, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# %%
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("Accuracy: ", str(accuracy_score(y_test, y_pred) * 100) + "%\n")
# Out:
# Confusion Matrix:
#  [[54  4]
#  [ 2 20]]
# Accuracy:  92.5%

# %%
tree.plot_tree(classifier)
# Out:
# [Text(0.4708333333333333, 0.9666666666666667, 'x[1] <= 0.611\ngini = 0.47\nsamples = 320\nvalue = [199, 121]'),
#  Text(0.25555555555555554, 0.9, 'x[2] <= 0.596\ngini = 0.311\nsamples = 228\nvalue = [184, 44]'),
#  Text(0.15555555555555556, 0.8333333333333334, 'x[1] <= -0.167\ngini = 0.082\nsamples = 186\nvalue = [178, 8]'),
#  Text(0.13333333333333333, 0.7666666666666667, 'gini = 0.0\nsamples = 120\nvalue = [120, 0]'),
#  Text(0.17777777777777778, 0.7666666666666667, 'x[2] <= 0.393\ngini = 0.213\nsamples = 66\nvalue = [58, 8]'),
#  Text(0.15555555555555556, 0.7, 'x[2] <= -0.07\ngini = 0.17\nsamples = 64\nvalue = [58, 6]'),
#  Text(0.13333333333333333, 0.6333333333333333, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.17777777777777778, 0.6333333333333333, 'x[2] <= 0.017\ngini = 0.312\nsamples = 31\nvalue = [25, 6]'),
#  Text(0.15555555555555556, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.5666666666666667, 'x[1] <= 0.319\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.15555555555555556, 0.5, 'x[1] <= 0.222\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.13333333333333333, 0.43333333333333335, 'x[2] <= 0.248\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.1111111111111111, 0.36666666666666664, 'x[2] <= 0.19\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.06666666666666667, 0.3, 'x[1] <= 0.027\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.044444444444444446, 0.23333333333333334, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.08888888888888889, 0.23333333333333334, 'x[2] <= 0.046\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.044444444444444446, 0.16666666666666666, 'x[1] <= 0.125\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.022222222222222223, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06666666666666667, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13333333333333333, 0.16666666666666666, 'x[1] <= 0.125\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1111111111111111, 0.1, 'x[2] <= 0.118\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08888888888888889, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13333333333333333, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15555555555555556, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15555555555555556, 0.3, 'x[0] <= 0.025\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13333333333333333, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17777777777777778, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15555555555555556, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17777777777777778, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.24444444444444444, 0.5, 'x[2] <= 0.118\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2222222222222222, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26666666666666666, 0.43333333333333335, 'x[0] <= 0.025\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.24444444444444444, 0.36666666666666664, 'x[2] <= 0.219\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2222222222222222, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26666666666666666, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.28888888888888886, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35555555555555557, 0.8333333333333334, 'x[1] <= -1.139\ngini = 0.245\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.3333333333333333, 0.7666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37777777777777777, 0.7666666666666667, 'x[2] <= 1.349\ngini = 0.214\nsamples = 41\nvalue = [5, 36]'),
#  Text(0.3111111111111111, 0.7, 'x[2] <= 1.089\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.28888888888888886, 0.6333333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.3333333333333333, 0.6333333333333333, 'x[1] <= -0.459\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3111111111111111, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35555555555555557, 0.5666666666666667, 'x[1] <= -0.362\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.3333333333333333, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37777777777777777, 0.5, 'x[0] <= 0.025\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.35555555555555557, 0.43333333333333335, 'x[1] <= 0.173\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3333333333333333, 0.36666666666666664, 'x[2] <= 1.233\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3111111111111111, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35555555555555557, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37777777777777777, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.7, 'x[1] <= 0.416\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.4222222222222222, 0.6333333333333333, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.4666666666666667, 0.6333333333333333, 'x[0] <= 0.025\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4444444444444444, 0.5666666666666667, 'x[2] <= 1.914\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4222222222222222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4666666666666667, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4888888888888889, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6861111111111111, 0.9, 'x[2] <= -0.824\ngini = 0.273\nsamples = 92\nvalue = [15, 77]'),
#  Text(0.5777777777777777, 0.8333333333333334, 'x[2] <= -1.374\ngini = 0.059\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.5555555555555556, 0.7666666666666667, 'x[1] <= 0.805\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5333333333333333, 0.7, 'x[1] <= 0.708\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5111111111111111, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5555555555555556, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5777777777777777, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.7666666666666667, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.7944444444444444, 0.8333333333333334, 'x[2] <= 0.451\ngini = 0.362\nsamples = 59\nvalue = [14, 45]'),
#  Text(0.7, 0.7666666666666667, 'x[1] <= 1.291\ngini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(0.6222222222222222, 0.7, 'x[1] <= 0.999\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.6, 0.6333333333333333, 'x[1] <= 0.805\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.5555555555555556, 0.5666666666666667, 'x[2] <= -0.519\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5333333333333333, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5777777777777777, 0.5, 'x[2] <= 0.19\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5555555555555556, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6, 0.43333333333333335, 'x[2] <= 0.306\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5777777777777777, 0.36666666666666664, 'x[1] <= 0.708\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5555555555555556, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6222222222222222, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6444444444444445, 0.5666666666666667, 'x[2] <= -0.635\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6222222222222222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6444444444444445, 0.6333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7777777777777778, 0.7, 'x[2] <= 0.364\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.7555555555555555, 0.6333333333333333, 'x[2] <= -0.751\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.7333333333333333, 0.5666666666666667, 'x[1] <= 2.069\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7111111111111111, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7555555555555555, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7777777777777778, 0.5666666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8888888888888888, 0.7666666666666667, 'x[1] <= 1.388\ngini = 0.208\nsamples = 34\nvalue = [4, 30]'),
#  Text(0.8666666666666667, 0.7, 'x[2] <= 0.668\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.8444444444444444, 0.6333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8888888888888888, 0.6333333333333333, 'x[2] <= 1.32\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.8444444444444444, 0.5666666666666667, 'x[1] <= 0.805\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8222222222222222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8666666666666667, 0.5, 'x[1] <= 1.145\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8444444444444444, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8888888888888888, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9333333333333333, 0.5666666666666667, 'x[2] <= 1.813\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.9111111111111111, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9555555555555556, 0.5, 'x[1] <= 1.291\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9333333333333333, 0.43333333333333335, 'x[0] <= 0.025\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9111111111111111, 0.36666666666666664, 'x[2] <= 1.914\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8888888888888888, 0.3, 'x[1] <= 1.097\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8666666666666667, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9111111111111111, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9333333333333333, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9555555555555556, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9777777777777777, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9111111111111111, 0.7, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]')]
